# %% [markdown]
# **Note: Remember to copy this exam into your Google drive before beginning!**

# %% [markdown]
# # Fall 2023 Midterm
#
# Welcome to your Fall 2023 Midterm Exam! Throughout the entire exam, your questions will be *thematic* such that each question should feel like a natural follow-up that a business executive or product manager would ask of you about your work. If you can work through this exam sufficiently, then you are well on your way to entering the workforce!
#
# Your exam questions will be both qualitative *and* quantitative—just as your work in real-life will be! As you work through your exam, be sure to *carefully* read through every question before answering it.
#
# This is a closed-book exam. The only time your screen should be off the `.ipynb` is if it's in canvas, or in the documentation I have provided to you below. I will be walking around to check, fam.
#
# **You have 1 hour and 15 minutes** to take your test and submit in Canvas in the `Midterm` link in the `Assignments` tab. Be sure that you **give yourself at least 5 minutes at the end of class** to ensure you have time to submit your exam.
#
# Deep breaths. You've got this.

# %% [markdown]
# General documentation you are allowed to use:
#
# * [ISLP Documentation](https://islp.readthedocs.io/en/latest/installation.html)
# * [Pandas Documentation](https://pandas.pydata.org/docs/reference/index.html)
# *   [Altair Documentation](https://altair-viz.github.io/user_guide/marks/index.html)
# * [scikit-learn Documentation](https://scikit-learn.org/stable/user_guide.html#)
# * [statsmodels Documentation](https://www.statsmodels.org/stable/user-guide.html)

# %% [markdown]
# # Exam Start
#
# This is it. You just graduated Chapman University `super-mega magna cum laude`, were given the key to the city by the Mayor of Orange, and were hired as a business analyst at the most exclusive, major finance firm ever: Atlas Worldwide Organized Outlay Finance (AWOOF). So life is going pretty great.
#
# It's your first day at work. You've arrived at AWOOF headquarters, walked up to your desk, and laying there is a piece of paper with some instructions for you:
#
# ```
# # Welcome to AWOOF, Whiz Kid! 🌍💼✨
#
# Dear [Your Name Here],
#
# First off, a super-sized, humongous, jumbo-tron CONGRATULATIONS! 🎉🎉
# Being a *super-mega magna cum laude* graduate is no small feat,
# nor is getting the key to a whole city! (Do remember to lock up after you're done.)
#
# I'm Mr. Bazzillion Bucks, the CEO of **AWOOF**. I've personally
# waited 17 years, 3 months, 27 days, 9 hours, 32 minutes, and... oh, about 17 seconds, to welcome someone
# of your caliber. So let's not waste any more precious milliseconds, shall we?
#
# I need you to get to work making money so I get buy more dog toys... I mean diamonds.
#
# Get to work.
#
# Doggedly Yours,
#
# 🖋️
# **Mr. Bazzillion Bucks**
# CEO of Atlas Worldwide Organized Outlay Finance
# ```

# %% [markdown]
# Below the letter are a list of tasks from Mr. Bazzillion Bucks. Better get to work!

# %% [markdown]
# # Question 1
#
# I want to understand how well we've been investing our money.
#
# a. Install the ISLP package, restart your runtime, load the `Smarket` dataset, and assign the data to the variable `market` (1pts)
#   - more info about the dataset found [here](https://islp.readthedocs.io/en/latest/datasets/Smarket.html)
#
# b. I want to understand which years trading `Direction` was more `Up` than `Down`. Group the data by `Year` and get the *counts of the values* by `Direction`. Then simply write in a comment which years were more up than down. (3pts) Hint: after grouping by a column, you can use double brackets `[[ ... ]]`
#
# c. I (Mr. Bazzillion Bucks) want pretty pictures. I don't understand data easily. Create an Altair plot of the data you created in problem b. (3pts)
#   - You should first *group* the original `market` data *by* Year, and get the value counts of the `Direction` data. You may need to reset the columns and rename the column. Assign that new DataFrame to a `yearly_market` variable. Hint: you can immediately rename a column like so: `reset_index(name="some_name")`
#   - On the x axis plot the year, on the y axis plot the name of your newly created column. **Make the chart a bar chart.**
#     - Ensure that `Year` is the correct data type before plotting! If your chart is wrong below, it will be marked down. See: [DataFrame.astype()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.astype.html)
#
#   - assign the 'Direction` column as the color in the encode step so I can see which data is down and up.
#
#
# You are allowed to use the [altair documentation](https://altair-viz.github.io/user_guide/marks/index.html). But only the altair documentation.

# %%
# a
! pip install ISLP
# Out:
# Requirement already satisfied: ISLP in /usr/local/lib/python3.10/dist-packages (0.3.21)
# Requirement already satisfied: numpy<1.25,>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from ISLP) (1.24.4)
# Requirement already satisfied: scipy>=0.9 in /usr/local/lib/python3.10/dist-packages (from ISLP) (1.11.3)
# Requirement already satisfied: pandas<=1.9,>=0.20 in /usr/local/lib/python3.10/dist-packages (from ISLP) (1.5.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from ISLP) (4.9.3)
# Requirement already satisfied: scikit-learn>=1.2 in /usr/local/lib/python3.10/dist-packages (from ISLP) (1.2.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from ISLP) (1.3.2)
# Requirement already satisfied: statsmodels>=0.13 in /usr/local/lib/python3.10/dist-packages (from ISLP) (0.14.0)
# Requirement already satisfied: lifelines in /usr/local/lib/python3.10/dist-packages (from ISLP) (0.27.8)
# Requirement already satisfied: pygam in /usr/local/lib/python3.10/dist-packages (from ISLP) (0.9.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from ISLP) (2.1.0+cu118)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.10/dist-packages (from ISLP) (2.1.1)
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.10/dist-packages (from ISLP) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas<=1.9,>=0.20->ISLP) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<=1.9,>=0.20->ISLP) (2023.3.post1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.2->ISLP) (3.2.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.13->ISLP) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.13->ISLP) (23.2)
# Requirement already satisfied: matplotlib>=3.0 in /usr/local/lib/python3.10/dist-packages (from lifelines->ISLP) (3.7.1)
# Requirement already satisfied: autograd>=1.5 in /usr/local/lib/python3.10/dist-packages (from lifelines->ISLP) (1.6.2)
# Requirement already satisfied: autograd-gamma>=0.3 in /usr/local/lib/python3.10/dist-packages (from lifelines->ISLP) (0.5.0)
# Requirement already satisfied: formulaic>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from lifelines->ISLP) (0.6.6)
# Requirement already satisfied: progressbar2<5.0.0,>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pygam->ISLP) (4.2.0)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning->ISLP) (4.66.1)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning->ISLP) (6.0.1)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning->ISLP) (2023.6.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning->ISLP) (4.5.0)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning->ISLP) (0.9.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->ISLP) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->ISLP) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->ISLP) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->ISLP) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->ISLP) (2.1.0)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.10/dist-packages (from autograd>=1.5->lifelines->ISLP) (0.18.3)
# Requirement already satisfied: astor>=0.8 in /usr/local/lib/python3.10/dist-packages (from formulaic>=0.2.2->lifelines->ISLP) (0.8.1)
# Requirement already satisfied: interface-meta>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from formulaic>=0.2.2->lifelines->ISLP) (1.3.0)
# Requirement already satisfied: wrapt>=1.0 in /usr/local/lib/python3.10/dist-packages (from formulaic>=0.2.2->lifelines->ISLP) (1.14.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning->ISLP) (2.31.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning->ISLP) (3.8.6)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->lifelines->ISLP) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->lifelines->ISLP) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->lifelines->ISLP) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->lifelines->ISLP) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->lifelines->ISLP) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->lifelines->ISLP) (3.1.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.2->statsmodels>=0.13->ISLP) (1.16.0)
# Requirement already satisfied: python-utils>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from progressbar2<5.0.0,>=4.2.0->pygam->ISLP) (3.8.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->ISLP) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->ISLP) (1.3.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning->ISLP) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning->ISLP) (3.3.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning->ISLP) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning->ISLP) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning->ISLP) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning->ISLP) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning->ISLP) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning->ISLP) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning->ISLP) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning->ISLP) (2023.7.22)

# %%
# a
from ISLP import load_data

market = load_data("Smarket")

# %%
# b
# Which years were up more than down?

result = (market.groupby("Year")[["Direction"]].value_counts().reset_index(name="Count"))
result

# 2003, 2004, 2005
# Out:
#    Year Direction  Count
# 0  2001      Down    125
# 1  2001        Up    117
# 2  2002      Down    140
# 3  2002        Up    112
# 4  2003        Up    138
# 5  2003      Down    114
# 6  2004        Up    140
# 7  2004      Down    112
# 8  2005        Up    141
# 9  2005      Down    111

# %%
# c
import altair as alt

yearly_market = market.groupby("Year")[['Direction']].value_counts().reset_index(name="Count")
yearly_market['Year'] = yearly_market['Year'].astype(str)

(
    alt.Chart(yearly_market)
       .mark_bar()
       .encode(x='Year', y='Count', color='Direction')
)
# Out:
# alt.Chart(...)

# %% [markdown]
# *After emailing Mr. Bazzillion Bucks your results, he only has more questions! Here is what he says:*
#
#
# # Question 2
#
# That chart was confusing! It was too small. And also that data didn't represent today. Let's try something else.
#
# - a. Load the `Fund` data from the ISLP package [here](https://islp.readthedocs.io/en/latest/datasets/Fund.html). Assign it to the variable `fund`. This is information about the managers I pay to trade my money around. I suspect that some are making systemically great trades. I want you to identify them. (1pt)
#
# - b. Take the median of every fund manager. *sort* the *values*. Assign this result to the variable `median_vals`. run `describe` on `median_vals`. Assign it to the variable `dist` and display its results. (2pts)
#
#
# - c. The `Empirical Rule`, or the `68-95-99.7 Rule`, says that around 68% of results should lie within 1 standard deviation of the mean, around 95% of scores within 2 standard deviations of the mean, and around 99.7% of scores should lie within 3 standard deviations of the mean, if we assume a normal distribution.
#
#   Assign the `mean` from `dist` to variable `mu`, and assign standard deviation from `dist` to the variable `sig`. Calculate what three standard deviations above the mean should be, assign it to the variable `three_sig_above`. (3pts)
#
# - d. Filter `median_vals` down to only include data that is greater than `three_sig_above`. Display who the underperformers are by printing out the filtered `median_vals` results. These are the managers who are systemically overperforming... They will be rewarded. (2pts)

# %%
# a
fund = load_data("Fund")

# b
median_vals = fund.median().sort_values()

dist = median_vals.describe()
dist
# Out:
# count    2000.000000
# mean       -0.015550
# std         1.549189
# min        -5.961558
# 25%        -0.899423
# 50%        -0.038731
# 75%         0.830911
# max         6.227548
# dtype: float64

# %%
# c
mu = dist['mean']
sig = dist['std']
three_sig_above= mu + (3*sig)

three_sig_above
# Out:
# 4.632015963235064

# %%
# d: systemic overperformers
median_vals[median_vals > three_sig_above]
# Out:
# Manager118     4.799317
# Manager1602    4.948836
# Manager57      4.999272
# Manager192     5.018994
# Manager91      5.248800
# Manager106     5.531031
# Manager68      5.684512
# Manager75      5.735545
# Manager180     5.970380
# Manager195     6.227548
# dtype: float64

# %% [markdown]
# *Well, you've sent your results to Mr. Bazzillion Bucks and he once again has more work for you...*
#
# # Question 3
#
# You did so well at identifying great fund managers, I thought maybe you could help me with something more advanced... One of the companies I'm thinking of buying has wage and demographic data of its workers found [here](https://islp.readthedocs.io/en/latest/datasets/Wage.html). I want to understand the trend of wages over time.
#
# - a. Load the `Wage` data into a variable `wages`. Sort the data by `Year`. Assign the sorted DataFrame back to `wages`. (1pt)
#
# - b. The data is pretty messy. We're going to have to fix that. (6pts)
#   - create a new `ever_college` column out of all text data in the column `education`. Assign a value to 1 if someone had any college or advanced education at all and 0 someone had only high school or less. (2pts)
#   - create a new `good_health` column out of all text data in the column `health`. Assign a value of 1 if someone has very good health or better, and a value of 0 if someone only had good health or less. (2pts)
#   - create a new `is_old` column out of all the numeric data in the column `age`. Assign a value of 1 if someone is 50 years of age or older, assign a value of 0 if someone is less than 50 (2pts).
#
# - c. [Split](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html) the data into training and test datasets. The training dataset should be 82% of the original data and the test dataset should be 18% of the original data. Assign them into variables `X_train, X_test, y_train, y_test`. The indepdenent variables should be: `year`, `age`, `ever_college`, `good_health`, `is_old`. The dependent variable should be: `logwage`. (3pts)
#   - *careful how you split your data here* this data is time sensitive so it cannot be treated randomly...
#
# - d. Please run a linear regression on the training data using the [`statsmodels.api` ols module](https://www.statsmodels.org/stable/regression.html). Make sure there is an intercept term/constant. Print out the summary results. (2pts)
#
# - e. Stats and Coefficients (8pts):
#   - Which independent variables are statistically significant at the five percent level? (2pts)
#   - Explain to me the expected relationship between those who are classified as is_old and logwage using the coefficient values provided and the language of a statistician. Hint: since `is_old` is a binary variable, you take its exponential before interpreting it. (3pts)
#   - If the goal was to predict logwages of workers, would you give this model to Mr Bazzillion Bucks? Why or why not? (Justify your answer rigorously). (3pts)

# %%
wages = load_data("Wage").sort_values('year').reset_index(drop=True)
wages.head()
# Out:
#    year  age       maritl      race        education              region  \
# 0  2003   39   2. Married  1. White       2. HS Grad  2. Middle Atlantic
# 1  2003   58   2. Married  1. White     1. < HS Grad  2. Middle Atlantic
# 2  2003   61  4. Divorced  1. White       2. HS Grad  2. Middle Atlantic
# 3  2003   29   2. Married  3. Asian       2. HS Grad  2. Middle Atlantic
# 4  2003   25   2. Married  1. White  3. Some College  2. Middle Atlantic
#
#         jobclass          health health_ins   logwage        wage
# 0  1. Industrial       1. <=Good      2. No  4.144605   63.092717
# 1  1. Industrial       1. <=Good      2. No  4.579784   97.493294
# 2  1. Industrial  2. >=Very Good     1. Yes  5.000000  148.413159
# 3  1. Industrial  2. >=Very Good     1. Yes  4.556303   95.230713
# 4  1. Industrial  2. >=Very Good     1. Yes  4.477121   87.981033

# %%
wages['education'].value_counts()
# Out:
# 2. HS Grad            971
# 4. College Grad       685
# 3. Some College       650
# 5. Advanced Degree    426
# 1. < HS Grad          268
# Name: education, dtype: int64

# %%
# ever_college

# different ways of achieving the same thing:
ever_college = [0 if i in ('2. HS Grad', '1. < HS Grad') else 1 for i in wages['education']]

# mapping = {'2. HS Grad': 0, '1. < HS Grad': 0, 'College Grad': 1, '3. Some College': 1, '5. Advanced Degree': 1}
# ever_college = wages['education'].map(mapping).tolist()

wages['ever_college'] = ever_college

# %%
wages['health'].value_counts()
# Out:
# 2. >=Very Good    2142
# 1. <=Good          858
# Name: health, dtype: int64

# %%
# good_health

# different ways of achieving the same thing:
good_health = [0 if i in ('1. <=Good') else 1 for i in wages['health']]

# mapping = {'1. <=Good': 0, '2. >=Very Good': 1}
# good_health = wages['health'].map(mapping).tolist()
# or
# good_health = wages['health'].apply(lambda x: 0 if x == '1. <=Good' else 1).tolist()

wages['good_health'] = good_health

# %%
# is_old

# different ways of achieving the same thing:
is_old = [0 if i < 50 else 1 for i in wages['age']]

# is_old = wages['age'].apply(lambda x: 0 if x < 50 else 1).tolist()

wages['is_old'] = is_old

# %%
from IPython.utils.path import random
from sklearn.model_selection import train_test_split

X = wages[['year','age', 'ever_college', 'good_health','is_old']]
y = wages['logwage']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.18, shuffle=False, random_state=5892)

# %%
import statsmodels.api as sm

X_train = sm.add_constant(X_train)

reg = sm.OLS(y_train, X_train).fit()

print(reg.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                logwage   R-squared:                       0.233
# Model:                            OLS   Adj. R-squared:                  0.232
# Method:                 Least Squares   F-statistic:                     149.5
# Date:                Sun, 12 Nov 2023   Prob (F-statistic):          7.34e-139
# Time:                        22:20:52   Log-Likelihood:                -584.69
# No. Observations:                2460   AIC:                             1181.
# Df Residuals:                    2454   BIC:                             1216.
# Df Model:                           5
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const          -29.8416      7.615     -3.919      0.000     -44.774     -14.909
# year             0.0169      0.004      4.445      0.000       0.009       0.024
# age              0.0107      0.001     12.780      0.000       0.009       0.012
# ever_college     0.2574      0.013     20.168      0.000       0.232       0.282
# good_health      0.1071      0.014      7.664      0.000       0.080       0.134
# is_old          -0.1291      0.021     -6.030      0.000      -0.171      -0.087
# ==============================================================================
# Omnibus:                      186.486   Durbin-Watson:                   1.954
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              700.210
# Skew:                          -0.297   Prob(JB):                    8.94e-153
# Kurtosis:                       5.545   Cond. No.                     2.47e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.47e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
#  e. Stats and cofficients
#  1. Every variable, including the intercept is statistically sigificant at least at the 5% level.
#  2. Compared to those who are not classified as "old" in our model, for those who are 50 years of age or older our model expects that they are associated with 88.3% of log wages compared to those younger than 50 or a 100*(1 - 0.883) = 12.11% decrease in the expected log wage of 50+ year old works, holding all else constant.
#  3. No. The R2 is incredibly low at .233 meaning the model does not capture much variance in the training data. It's hard to imagine it would capture **more** variance out of sample. We can confidently claim this model is underfit.

# %%
from math import exp
exp(-0.12391)
# Out:
# 0.883459348646226

# %% [markdown]
# *After you've emailed your results to Mr. Bazzillion Bucks, he responded with a final set of questions for you*
#
# # Question 4
#
# Great! You've answered all my questions. Answer these last questions for me and I will exit my office and reveal myself to you!
#
# We are thinking of getting into the credit game. Assess this credit dataset for me and tell me what you think.
#
# - a. Load the [`Credit`](https://islp.readthedocs.io/en/latest/datasets/Credit.html) dataset from ISLP. Assign it to the `credit` variable. Create a target variable for us: whenever the column `Limit` is above 6000 assign a 1, otherwise assign a 0. Assign these results to a new column: `is_high`. (2pts)
# - b. Create new features for us. In the `Gender` column map those who are assigned ' Male' to 1 and those who are assigned 'Female' 0. Assign the new data to the column `is_male` (2pts). Hint: The Male column has a typo...
# - c. Create another new feature column. In the `Education` column assign values 16 and above to 1, and all other values to 0. Assign the results to the new column `is_educated`. (2pts)
# - d. Run a train_test_split on the credit dataset. The feature data should be: `'Income', 'Rating', 'Cards', 'Age', 'Education', 'Balance', 'is_male', 'is_educated' `. The target should be `is_high` from above. The test_size should be .17. The data should be shuffled and a `random_state` integer should be given so I can recreate your work. (2pts)
# - e. Run a [LogisticRegression](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html) on your `X_train` and `y_train` data. Then predict on your `X_test` data. (2pts)
# - f. Run a [confusion matrix](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html) on your results. Interpret your results for me. Interpret every cell in the matrix. (4pts)
# - g. Run an [ROC/AUC score](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_auc_score.html#sklearn.metrics.roc_auc_score) on your data. Are the results good? How do you know? Would you put this model into production in the real world? Why or why not? Intepret the AUC value for us. (4pts)

# %%
# a

credit = load_data('Credit')
credit['is_high'] = (credit['Limit'] > 6000).astype(int)

# # another method
# # credit['is_high'] = credit['Rating'].map(lambda x: 1 if x > 6000 else 0)

# credit.shape

# %%
# b
gender_mapping = {" Male": 1, "Female": 0}
credit['is_male'] = credit['Gender'].map(gender_mapping)

# %%
# c

credit['is_educated'] = [1 if i >= 16 else 0 for i in credit['Education']]

# %%
# d.
X = credit[['Income', 'Rating', 'Cards', 'Age', 'Education', 'Balance', 'is_male', 'is_educated']]
y = credit['is_high']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.17,
                                                    random_state=643, shuffle=True)

# %%
#e.
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = log_reg.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, y_pred)
# Out:
# array([[45,  0],
#        [ 4, 19]])

# %% [markdown]
# - The results are pretty great! We have 19 True Negatives and 45 True Positives. predicted our True Positives and True Negatives in our out of sample prediction. That means the model generalizes very well. We predicted 4 False Negatives and 0 False Positive.

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test, y_pred)
# Out:
# 0.9130434782608696

# %%
# g

# The results are high at ~.91. The best we can hope for is 1.0, the worst is 0.
# I still wonder if we should put it into production because in the real world,
# data is going to be messier and we only trained on 400 data points.
# There's always going to be exceptions we haven't seen, but 400 seems unreasonably too low
# It can lead one to wonder if the model is overfit. We probably want to test on more data.
# Still, if someone did put it into production, it wouldn't be the worst in the world.

# %% [markdown]
# As you finish your results and send them in, Mr. Bazzillion Bucks exits his CEO office and you get to see who he is for the first time... Run the code below to find out who this myster CEO is!

# %%
# Run this code if you have time, otherwise submit your notebook!
from IPython.display import Image, display

print("Mr Bazzillion Bucks was Atlas!")

image_url = "https://user-images.githubusercontent.com/45580612/275377290-33ebb2ba-37bd-4d20-a9cd-f8ae70fb21ed.jpeg"
display(Image(url=image_url, width=450, height=500))
# Out:
# Mr Bazzillion Bucks was Atlas!
# <img src="https://user-images.githubusercontent.com/45580612/275377290-33ebb2ba-37bd-4d20-a9cd-f8ae70fb21ed.jpeg" width="450" height="500"/>

# %% [markdown]
# ### Submit your exam in Canvas!
