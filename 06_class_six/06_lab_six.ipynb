# %% [markdown]
# Recall! You must copy this notebook to your own Drive before using!

# %% [markdown]
# # **Lab Six: Summary Stastics with Group By and Apply**

# %% [markdown]
# ## **Connect To Your Google Drive**
#
# Here we want to ensure you're able to connect to google drive. If you are unable to connect, try using a different browser like Safari or Edge.

# %%
from os import environ
from google.colab import drive

# if we are starting here we need to remount our drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### So Mounting Your Drive Programmatically Has Failed...
#
# If you, like me, and have had trouble like above connecting to Google Drive, fear not! Alternative routes exist. Follow these instructions:
#
#
#
# 1.   Go to `View` located at the top ribbon within the notebook (between `Edit` and `Insert`).
# 2.   Select `Table of Contents`
# 3.   Click on the `file` icon as seen below:
#
# ![Screenshot 2023-08-11 at 5.11.12 PM.png](data:image/png;base64,...)
#
# 4.   Mount Drive!
#
# ![Screenshot 2023-08-11 at 5.13.43 PM.png](data:image/png;base64,...)

# %% [markdown]
# # Pre-requisite
# Read In the IMDB Dataset to a pandas DataFrame

# %% [markdown]
# # Question 1
#
# Run the Pandas function (method) that shows the descriptive statistics for the IMDB dataset.

# %% [markdown]
# # Question 2
#
# Create an Altair box and whisker plot for the `duration` column in the IMDB `DataFrame`. Title it "Box and Whisker Plot of IMDB Duration" and make it interactive.

# %% [markdown]
# # Question 3
#
# Using `.describe()`, calculate the [Interquartile Range (IQR)](https://en.wikipedia.org/wiki/Interquartile_range) of the `duration` column in the IMDB dataset.

# %% [markdown]
# # Question 4
#
# Using groupby and apply, write group by `title_year`, then calculate the average `gross` and average `budget` per year. Ensure you do not show any other columns (hint: filter by `title_year`, `gross`, and `budget` first).

# %% [markdown]
# # Question 5
# Using your the results from Question 5, calculate the a new column `average_profit` per year using `.assign` and `lambda x:`.
