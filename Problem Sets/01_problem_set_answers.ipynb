# %% [markdown]
# # Student and Problem Set Info
# ---
#
#
# ## Title: MGSC 310: Problem Set 1
#
# Author:
#
# Ben Labaschin, King of the Notebooks, Destroyer of Worlds.

# %% [markdown]
# # Libraries

# %%
from os import environ
from google.colab import drive

# %% [markdown]
# # Setup

# %%
# Ensure you run this cell or otherwise connect to your Google Drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Question 1
#
# Using what you learned in Lab 1 "but I want to set up my own working directory" connect set your `working directory` to `MGSC_310_shared_files_and_resources/03_class_three/`
#
# Tip: when poviding the current directory function a path, try starting with the absolute path prefix: `/content/drive/MyDrive/`

# %%
from os import ______ # <-- replace with the correct function

path_I_want_as_my_working_directory = "/content/drive/MyDrive/" + "<PLACE A PATH HERE>"

# %% [markdown]
# # Answer 1

# %%
from os import chdir

path_I_want_as_my_working_directory = "/content/drive/MyDrive/Work/Chapman/MGSC_310/MGSC_310_shared_files_and_resources/03_class_three/"

chdir(path_I_want_as_my_working_directory)

# %% [markdown]
# # Question 2
#
# a). Import the `listdir` function from the `os` module and run it.
#
# b). In your own words, what does this function do?

# %%
from __ import ______ # fill in this with the proper terms!

# then run the function!

# %% [markdown]
# # Answer 2

# %% [markdown]
# a).

# %%
from os import listdir

listdir()
# Out:
# ['IMDB_movies.csv',
#  'Effective Data Science: Notes from a Recovering Data Scientist.gslides',
#  '03_effective_data_science_and_visuals.ipynb']

# %% [markdown]
# b).
# `listdir`: Return a list containing the names of the files in the directory.

# %% [markdown]
# # Question 3
#
# a). Read in the file `IMDB_movies.csv` using the `pandas` function `read_csv` and assign the `DataFrame` to a variable called `movies`
#
# b). Print out how many columns and rows are in the `movies` `DataFrame`. Leave a comment explicitly stating how many rows there are and how many columns there are (e.g. # COLUMNS: ____ , ROWS: _____)
#
#
# c). Look at [this pandas documentation](https://www.w3schools.com/python/pandas/ref_df_columns.asp). Based on its instructions, print out the column names contained in the `movies` `DataFrame`
#
#
# d)
#
# For each numeral below, use the results from the preceding numeral to complete your work.
# 1. Print out the data types of each of these columns.
# 2. Which `movies` columns are string objects (HINT! [you can filter by 'object' types](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.select_dtypes.html))?
#
#
# e) Read the official `iloc[]` pandas documentation [here](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.iloc.html) (pay close attention to the examples!) Filter the `movies` dataset to its first 20 rows using `iloc`.
#
#
# f)
# For each numeral below, use the results from the preceding numeral to complete your work.
# 1. Use the `sort_values(by=...)` function (documentation [here](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html?highlight=sort_values#pandas.DataFrame.sort_values)) to order the `movies` `DataFrame` *in descending order* by `gross` or total boxoffice revenue in $USD.
# 2. Use the slice function to show the ten movies with the largest boxoffice revenue in the dataset.
# 3. Which director or directors have multiple movies among the top 10 highest grossing films of all time.

# %% [markdown]
# # Answer 3

# %% [markdown]
# a)

# %%
from pandas import read_csv

movies = read_csv("./IMDB_movies.csv")

# %% [markdown]
# b)

# %%
movies.shape

# ROWS: 3889, COLUMNS: 25
# Out:
# (3889, 25)

# %% [markdown]
# c).

# %%
# print out column names here

movies.columns
# Out:
# Index(['movie_title', 'director_name', 'gross', 'budget', 'country',
#        'title_year', 'imdb_score', 'language', 'duration', 'genres',
#        'content_rating', 'aspect_ratio', 'color', 'plot_keywords',
#        'movie_facebook_likes', 'director_facebook_likes',
#        'cast_total_facebook_likes', 'facenumber_in_poster',
#        'actor_1_facebook_likes', 'actor_1_name', 'actor_2_facebook_likes',
#        'actor_2_name', 'num_user_for_reviews', 'num_critic_for_reviews',
#        'num_voted_users'],
#       dtype='object')

# %% [markdown]
# d).

# %%
### d1:

print(movies.dtypes, '\n')

#### d2: Variables that are String Objects (can also be written out manually, I'm just a lazy programmer)

print(movies.select_dtypes('object').columns)
# Out:
# movie_title                   object
# director_name                 object
# gross                          int64
# budget                         int64
# country                       object
# title_year                     int64
# imdb_score                   float64
# language                      object
# duration                     float64
# genres                        object
# content_rating                object
# aspect_ratio                 float64
# color                         object
# plot_keywords                 object
# movie_facebook_likes           int64
# director_facebook_likes        int64
# cast_total_facebook_likes      int64
# facenumber_in_poster         float64
# actor_1_facebook_likes       float64
# actor_1_name                  object
# actor_2_facebook_likes       float64
# actor_2_name                  object
# num_user_for_reviews           int64
# num_critic_for_reviews       float64
# num_voted_users                int64
# dtype: object
#
# ...

# %% [markdown]
# e).

# %%
movies.iloc[:20, :]
# Out:
#                                     movie_title  ... num_voted_users
# 0                                        Avatar  ...          886204
# 1      Pirates of the Caribbean: At World's End  ...          471220
# 2                                       Spectre  ...          275868
# 3                         The Dark Knight Rises  ...         1144337
# 4                                   John Carter  ...          212204
# 5                                  Spider-Man 3  ...          383056
# 6                                       Tangled  ...          294810
# 7                       Avengers: Age of Ultron  ...          462669
# 8        Harry Potter and the Half-Blood Prince  ...          321795
# 9            Batman v Superman: Dawn of Justice  ...          371639
# 10                             Superman Returns  ...          240396
# 11                            Quantum of Solace  ...          330784
# 12   Pirates of the Caribbean: Dead Man's Chest  ...          522040
# ...

# %% [markdown]
# f).

# %%
# f1
sorted_movies = movies.sort_values(by='gross', ascending=False)
sorted_movies
# Out:
#                     movie_title  ... num_voted_users
# 0                        Avatar  ...          886204
# 25                      Titanic  ...          793059
# 28               Jurassic World  ...          418214
# 16                 The Avengers  ...          995415
# 758                The Avengers  ...          995415
# ...                         ...  ...             ...
# 3775      Detention of the Dead  ...            2038
# 3841  The Trials of Darryl Hunt  ...             771
# 3701        In Her Line of Fire  ...             783
# 3702             The Jimmy Show  ...             480
# 2947                 Skin Trade  ...            5228
#
# [3889 rows x 25 columns]

# %%
# f2
sorted_movies.iloc[:10,:]
# Out:
#                                     movie_title  ... num_voted_users
# 0                                        Avatar  ...          886204
# 25                                      Titanic  ...          793059
# 28                               Jurassic World  ...          418214
# 16                                 The Avengers  ...          995415
# 758                                The Avengers  ...          995415
# 64                              The Dark Knight  ...         1676169
# 232   Star Wars: Episode I - The Phantom Menace  ...          534658
# 2725         Star Wars: Episode IV - A New Hope  ...          911097
# 7                       Avengers: Age of Ultron  ...          462669
# 3                         The Dark Knight Rises  ...         1144337
#
# [10 rows x 25 columns]

# %%
# f3: answer can be manually written as well, but I'm lazy.
sorted_movies.iloc[:10,:][sorted_movies.iloc[:10,:].duplicated(subset="director_name")]
# Out:
#                              movie_title  ... num_voted_users
# 25                               Titanic  ...          793059
# 758                         The Avengers  ...          995415
# 2725  Star Wars: Episode IV - A New Hope  ...          911097
# 7                Avengers: Age of Ultron  ...          462669
# 3                  The Dark Knight Rises  ...         1144337
#
# [5 rows x 25 columns]

# %% [markdown]
# # Question 4
#
# Suppose you are a data scientist hired by a large clothing retailer in the US. Think of one causal and one predictive analysis that you could implement that could help clothing stores navigate the pressure of rising inflation.

# %% [markdown]
# # Answer 4

# %% [markdown]
# This is an open-ended question. Some possible answers:
#
# Causal Analysis
#
# Setup a double-blind randomized controlled trial to assess whether shoppers are price elastic or inelastic when it comes to inflation by raising the prices of some clothes in some stores, but not in others, controlling for independent variables like time of year and location
#
#
# Predictive Analysis
#
# Run a survival analysis using online shopper data to determine predict when shoppers stop shopping at your store, then run an intervention campaign, offering discounts, and analyze the affect of the campaign on LTV.
