# %% [markdown]
# # Student and Problem Set Info
# ---
# Problem Set: "[Replace with Problem Set Title/Number]"
#
# Author: "[Replace with your name]"
#
# subtitle: MGSC 310 Problem Set Template

# %% [markdown]
# # Libraries

# %%
 # place all your library imports here! get into the practice! libraries always go at the top!

# %% [markdown]
# # Question 1

# %% [markdown]
# 1a). Text response to part 1a.

# %%
# Code response to 1a

# %% [markdown]
# 1b). Text response to part 1b.

# %%
# Code response to 1b

# %% [markdown]
# 1c). Text response to part 1c.

# %%
# Code response to 1c.

# %% [markdown]
# # Question 2

# %% [markdown]
# 2a). Text response to part 2a.

# %%
# Code response to 2a

# %% [markdown]
# 2b). Text response to part 2b.

# %%
# Code response to 2b

# %% [markdown]
# 2c). Test response to 2c.

# %%
# Code response to 2c

# %% [markdown]
# # Question 3

# %% [markdown]
# 3a). Text response to part 3a)

# %%
# Code response to 3a

# %% [markdown]
# 3b). Text response to part 3b.

# %%
# Code response to 3b

# %% [markdown]
# 3c). Text response to part 3c.

# %%
# Code response to 3c

# %% [markdown]
# # Question 4
#
# Here is only text for question 4.
#
# If you want to add a hypertext link, you can do so like [this](https://youtu.be/dQw4w9WgXcQ).
#
# If you want to add bullets:
# - You
# - Can
# - Do
# - It
